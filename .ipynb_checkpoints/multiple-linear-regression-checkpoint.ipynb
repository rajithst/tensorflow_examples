# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer
# Out:
# WARNING:tensorflow:From /Users/rajith/opt/anaconda3/envs/tensorflow_play/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
dataset = pd.read_csv("data/auto-mpg-processed.csv")

# %%
X = dataset[["displacement","horsepower","weight"]].values
y = dataset["mpg"]

# %% [markdown]
# ### baseline implementation

# %%
#X = Normalizer().fit_transform(X)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
y_train = y_train.values.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (313, 3)
# (313, 1)
# (79, 3)
# (79, 1)

# %%
model = LinearRegression(normalize=True)
model.fit(X_train,y_train)
print("Training score: ",model.score(X_train,y_train))
print("Coefficents ",model.coef_)
print("Intercept ",model.intercept_)
# Out:
# Training score:  0.70596665956808
# Coefficents  [[-0.00721057 -0.04214167 -0.00520016]]
# Intercept  [44.56120579]

# %% [markdown]
# ### Tensorflow Implementation

# %%
num_train_samples = X_train.shape[0]
n_features = X_train.shape[1]

# %%
tf_x = tf.placeholder(tf.float32,shape=[None,n_features],name="input_x")
tf_y = tf.placeholder(tf.float32,shape=[None,1],name="input_y")

# %%
W = tf.Variable(tf.zeros([n_features,1]),name="W")
b = tf.Variable(tf.zeros([1]),name="b")

# %%
tf_pred = tf.add(tf.matmul(tf_x,W),b)

# %%
tf_cost = tf.reduce_sum(tf.pow(tf_pred-tf_y,2))/(2*num_train_samples)

# %%
learning_rate = 0.0001
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(tf_cost)

# %%
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    num_train_iter = 50
    for iteration in range(num_train_iter):
        for (x,y) in zip(X_train,y_train):
            sess.run(optimizer,feed_dict={tf_x:x.reshape(1,-1),tf_y:y.reshape(1,-1)})
        c = sess.run(tf_cost,feed_dict={tf_x:X_train,tf_y:y_train})
        print(f"Iteration #{iteration} cost={c}")
# Out:
# Iteration #0 cost=84.47395324707031
# Iteration #1 cost=76.5250244140625
# Iteration #2 cost=68.5289077758789
# Iteration #3 cost=61.43342971801758
# Iteration #4 cost=55.58356475830078
# Iteration #5 cost=51.0230598449707
# Iteration #6 cost=47.63849639892578
# Iteration #7 cost=45.239253997802734
# Iteration #8 cost=43.60734176635742
# Iteration #9 cost=42.531612396240234
# Iteration #10 cost=41.831295013427734
# Iteration #11 cost=41.36886978149414
# Iteration #12 cost=41.05187225341797
# Iteration #13 cost=40.825260162353516
# Iteration #14 cost=40.65895080566406
# Iteration #15 cost=40.53595733642578
# Iteration #16 cost=40.444618225097656
# Iteration #17 cost=40.375244140625
# Iteration #18 cost=40.31966018676758
# Iteration #19 cost=40.27155685424805
# Iteration #20 cost=40.2268180847168
# Iteration #21 cost=40.18315887451172
# Iteration #22 cost=40.13962173461914
# Iteration #23 cost=40.09591293334961
# Iteration #24 cost=40.052001953125
# Iteration #25 cost=40.007938385009766
# Iteration #26 cost=39.963768005371094
# Iteration #27 cost=39.91951370239258
# Iteration #28 cost=39.875221252441406
# Iteration #29 cost=39.83090591430664
# Iteration #30 cost=39.786582946777344
# Iteration #31 cost=39.74226379394531
# Iteration #32 cost=39.69794845581055
# Iteration #33 cost=39.65365982055664
# Iteration #34 cost=39.609371185302734
# Iteration #35 cost=39.56512451171875
# Iteration #36 cost=39.52090835571289
# Iteration #37 cost=39.47670364379883
# Iteration #38 cost=39.432518005371094
# Iteration #39 cost=39.38837432861328
# Iteration #40 cost=39.344566345214844
# Iteration #41 cost=39.300174713134766
# Iteration #42 cost=39.25614547729492
# Iteration #43 cost=39.21210861206055
# Iteration #44 cost=39.16814041137695
# Iteration #45 cost=39.12416458129883
# Iteration #46 cost=39.08124923706055
# Iteration #47 cost=39.03634262084961
# Iteration #48 cost=38.99265670776367
# Iteration #49 cost=38.94865798950195

# %%
y_train.shape
# Out:
# (313, 1)

# %%
X_train.values
# Out:
# array([[ 307. ,  130. , 4098. ],
#        [  97. ,   67. , 1985. ],
#        [ 140. ,   88. , 2890. ],
#        [ 112. ,   85. , 2575. ],
#        [ 302. ,  129. , 3725. ],
#        [ 113. ,   95. , 2228. ],
#        [ 302. ,  140. , 4294. ],
#        [  86. ,   65. , 2110. ],
#        [ 250. ,   72. , 3432. ],
#        [ 101. ,   83. , 2202. ],
#        [  90. ,   48. , 1985. ],
#        [  97. ,   78. , 2300. ],
#        [ 122. ,   86. , 2395. ],
#        [ 318. ,  150. , 4077. ],
#        [ 111. ,   80. , 2155. ],
#        [ 262. ,   85. , 3015. ],
#        [ 151. ,   90. , 2950. ],
#        [ 302. ,  140. , 4141. ],
#        [ 231. ,  110. , 3907. ],
#        [  97. ,   88. , 2100. ],
#        [ 231. ,  105. , 3535. ],
#        [ 250. ,  105. , 3353. ],
#        [  98. ,   76. , 2144. ],
#        [ 151. ,   90. , 2670. ],
#        [ 200. ,   88. , 3060. ],
#        [ 400. ,  170. , 4668. ],
#        [ 151. ,   90. , 2678. ],
#        [  98. ,   80. , 2164. ],
#        [ 258. ,   95. , 3193. ],
#        [ 116. ,   75. , 2246. ],
#        [ 302. ,  140. , 4638. ],
#        [  79. ,   67. , 1950. ],
#        [ 304. ,  150. , 3672. ],
#        [ 198. ,   95. , 2904. ],
#        [  78. ,   52. , 1985. ],
#        [ 119. ,  100. , 2615. ],
#        [ 225. ,  100. , 3651. ],
#        [ 140. ,   75. , 2542. ],
#        [ 250. ,  100. , 3282. ],
#        [ 350. ,  145. , 4440. ],
#        [ 350. ,  155. , 4360. ],
#        [ 200. ,   85. , 3070. ],
#        [ 108. ,   75. , 2350. ],
#        [  97. ,   52. , 2130. ],
#        [ 250. ,  105. , 3897. ],
#        [ 304. ,  150. , 3892. ],
#        [ 455. ,  225. , 4425. ],
#        [ 318. ,  150. , 3940. ],
#        [ 318. ,  150. , 4457. ],
#        [ 135. ,   84. , 2525. ],
#        [ 350. ,  125. , 3900. ],
#        [ 113. ,   95. , 2278. ],
#        [ 304. ,  150. , 4257. ],
#        [ 140. ,   72. , 2565. ],
#        [ 400. ,  180. , 4220. ],
#        [ 305. ,  140. , 4215. ],
#        [ 351. ,  142. , 4054. ],
#        [ 250. ,   78. , 3574. ],
#        [ 200. ,   81. , 3012. ],
#        [ 232. ,   90. , 3265. ],
#        [ 120. ,   97. , 2506. ],
#        [ 383. ,  180. , 4955. ],
#        [ 267. ,  125. , 3605. ],
#        [ 119. ,   97. , 2405. ],
#        [ 198. ,   95. , 3102. ],
#        [ 151. ,   88. , 2740. ],
#        [ 232. ,  112. , 2835. ],
#        [ 250. ,   88. , 3021. ],
#        [  79. ,   67. , 1963. ],
#        [ 231. ,  165. , 3445. ],
#        [ 454. ,  220. , 4354. ],
#        [  71. ,   65. , 1836. ],
#        [ 122. ,   86. , 2220. ],
#        [  79. ,   67. , 2000. ],
#        [ 250. ,  110. , 3645. ],
#        [ 225. ,  110. , 3620. ],
#        [  85. ,   70. , 2070. ],
#        [ 350. ,  165. , 4274. ],
#        [ 350. ,  175. , 4100. ],
#        [ 173. ,  115. , 2700. ],
#        [ 250. ,   88. , 3302. ],
#        [ 351. ,  153. , 4154. ],
#        [ 119. ,   92. , 2434. ],
#        [ 163. ,  133. , 3410. ],
#        [ 351. ,  138. , 3955. ],
#        [ 429. ,  198. , 4341. ],
#        [ 350. ,  150. , 4699. ],
#        [ 168. ,  132. , 2910. ],
#        [  97. ,   71. , 1825. ],
#        [ 146. ,   97. , 2815. ],
#        [ 135. ,   84. , 2370. ],
#        [ 130. ,  102. , 3150. ],
#        [ 225. ,  105. , 3121. ],
#        [  97. ,   78. , 2190. ],
#        [ 141. ,   71. , 3190. ],
#        [  97. ,   67. , 2065. ],
#        [ 120. ,   74. , 2635. ],
#        [ 134. ,   95. , 2515. ],
#        [ 225. ,  100. , 3430. ],
#        [ 305. ,  130. , 3840. ],
#        [ 122. ,   85. , 2310. ],
#        [ 173. ,  110. , 2725. ],
#        [ 146. ,  120. , 2930. ],
#        [ 350. ,  170. , 4165. ],
#        [ 232. ,  100. , 3288. ],
#        [  85. ,   65. , 1975. ],
#        [ 232. ,  100. , 2634. ],
#        [ 232. ,  100. , 2789. ],
#        [ 120. ,   79. , 2625. ],
#        [ 121. ,  110. , 2600. ],
#        [ 121. ,   67. , 2950. ],
#        [ 440. ,  215. , 4735. ],
#        [ 250. ,   72. , 3158. ],
#        [ 135. ,   84. , 2385. ],
#        [ 107. ,   75. , 2205. ],
#        [ 151. ,   90. , 3003. ],
#        [  97. ,   75. , 2155. ],
#        [ 302. ,  129. , 3169. ],
#        [ 351. ,  152. , 4215. ],
#        [ 156. ,   92. , 2620. ],
#        [ 360. ,  215. , 4615. ],
#        [ 440. ,  215. , 4312. ],
#        [ 318. ,  150. , 4498. ],
#        [  76. ,   52. , 1649. ],
#        [ 225. ,  100. , 3233. ],
#        [ 360. ,  175. , 3821. ],
#        [  70. ,  100. , 2420. ],
#        [ 120. ,   88. , 2160. ],
#        [  85. ,   70. , 1990. ],
#        [ 232. ,   90. , 3210. ],
#        [ 400. ,  190. , 4325. ],
#        [ 105. ,   63. , 2125. ],
#        [ 383. ,  170. , 3563. ],
#        [ 108. ,   75. , 2265. ],
#        [ 250. ,  100. , 3781. ],
#        [ 131. ,  103. , 2830. ],
#        [ 140. ,   72. , 2401. ],
#        [  97.5,   80. , 2126. ],
#        [ 112. ,   88. , 2605. ],
#        [ 225. ,   95. , 3264. ],
#        [ 119. ,   97. , 2300. ],
#        [ 114. ,   91. , 2582. ],
#        [  91. ,   67. , 1965. ],
#        [ 250. ,  110. , 3520. ],
#        [ 400. ,  190. , 4422. ],
#        [ 232. ,  100. , 2901. ],
#        [ 250. ,  100. , 3329. ],
#        [ 198. ,   95. , 2833. ],
#        [ 232. ,  100. , 2914. ],
#        [ 156. ,   92. , 2585. ],
#        [ 318. ,  210. , 4382. ],
#        [ 155. ,  107. , 2472. ],
#        [ 225. ,  105. , 3439. ],
#        [ 199. ,   90. , 2648. ],
#        [ 231. ,  110. , 3039. ],
#        [ 122. ,   80. , 2451. ],
#        [ 258. ,  110. , 3730. ],
#        [  98. ,   68. , 2135. ],
#        [  98. ,   66. , 1800. ],
#        [  88. ,   76. , 2065. ],
#        [ 429. ,  208. , 4633. ],
#        [ 105. ,   63. , 2215. ],
#        [  97. ,   60. , 1834. ],
#        [  97. ,   54. , 2254. ],
#        [ 400. ,  150. , 3761. ],
#        [ 400. ,  150. , 4997. ],
#        [ 351. ,  153. , 4129. ],
#        [  70. ,   90. , 2124. ],
#        [  91. ,   68. , 2025. ],
#        [  97. ,   88. , 2130. ],
#        [  97. ,   78. , 2188. ],
#        [ 302. ,  139. , 3205. ],
#        [ 258. ,  110. , 3632. ],
#        [ 225. ,  110. , 3360. ],
#        [ 121. ,  115. , 2671. ],
#        [  86. ,   64. , 1875. ],
#        [ 151. ,   90. , 2556. ],
#        [ 340. ,  160. , 3609. ],
#        [  90. ,   48. , 2335. ],
#        [ 140. ,   92. , 2865. ],
#        [ 121. ,  110. , 2660. ],
#        [  98. ,   83. , 2075. ],
#        [ 121. ,  112. , 2868. ],
#        [ 305. ,  145. , 3425. ],
#        [  97. ,   75. , 2171. ],
#        [ 105. ,   70. , 2200. ],
#        [ 122. ,   88. , 2500. ],
#        [  83. ,   61. , 2003. ],
#        [ 350. ,  180. , 3664. ],
#        [  80. ,  110. , 2720. ],
#        [  71. ,   65. , 1773. ],
#        [ 140. ,   92. , 2572. ],
#        [ 351. ,  158. , 4363. ],
#        [ 120. ,   88. , 2957. ],
#        [ 112. ,   88. , 2640. ],
#        [  89. ,   60. , 1968. ],
#        [ 105. ,   75. , 2230. ],
#        [ 140. ,   88. , 2870. ],
#        [ 307. ,  200. , 4376. ],
#        [ 200. ,   85. , 2965. ],
#        [  85. ,   65. , 2020. ],
#        [ 350. ,  180. , 4499. ],
#        [ 200. ,   95. , 3155. ],
#        [ 400. ,  175. , 4385. ],
#        [  90. ,   75. , 2108. ],
#        [  89. ,   62. , 1845. ],
#        [ 121. ,  112. , 2933. ],
#        [ 119. ,   97. , 2545. ],
#        [ 120. ,   88. , 3270. ],
#        [ 225. ,  100. , 3630. ],
#        [ 107. ,   75. , 2210. ],
#        [ 250. ,  105. , 3459. ],
#        [ 113. ,   95. , 2372. ],
#        [ 104. ,   95. , 2375. ],
#        [ 183. ,   77. , 3530. ],
#        [ 232. ,  100. , 2945. ],
#        [  98. ,   70. , 2125. ],
#        [ 318. ,  145. , 4140. ],
#        [ 151. ,   90. , 2735. ],
#        [ 302. ,  140. , 3449. ],
#        [  98. ,   80. , 1915. ],
#        [ 107. ,   72. , 2290. ],
#        [  79. ,   70. , 2074. ],
#        [ 110. ,   87. , 2672. ],
#        [ 225. ,  105. , 3613. ],
#        [  97. ,   46. , 1835. ],
#        [ 140. ,   86. , 2790. ],
#        [  90. ,   71. , 2223. ],
#        [ 318. ,  135. , 3830. ],
#        [  85. ,   65. , 2110. ],
#        [ 400. ,  150. , 4464. ]])
